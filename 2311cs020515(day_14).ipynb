# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
iris_data=sns.load_dataset('iris')
df=sns.load_dataset('taxis')

# %%
sns.stripplot(x=df['payment'],y=df['tip'],palette=['r','g'])
plt.show()

# %%
sns.lineplot(x=df['tip'],y=df['fare'])
plt.show()

# %%
sns.lineplot(x=df['tip'],y=df['total'])
plt.show()

# %%
sns.lineplot(x=df['total'],y=df['fare'],palette=['r','g'])
plt.show()

# %%
sns.lineplot(x=df['total'],y=df['fare'],hue=df['payment'],palette=['red','green'])
plt.show()

# %%
df[(df['payment']=='cash') & (df['tip']>1)]
# Out:
# Empty DataFrame
# Columns: [pickup, dropoff, passengers, distance, fare, tip, tolls, total, color, payment, pickup_zone, dropoff_zone, pickup_borough, dropoff_borough]
# Index: []

# %%
df[['payment','color']].value_counts()
# Out:
# payment      color
# credit card  yellow    4000
# cash         yellow    1412
# credit card  green      577
# cash         green      400
# Name: count, dtype: int64

# %%
df['color'].value_counts()
# Out:
# color
# yellow    5451
# green      982
# Name: count, dtype: int64

# %%
df['payment'].value_counts()
# Out:
# payment
# credit card    4577
# cash           1812
# Name: count, dtype: int64

# %%
sns.countplot(x=df['payment'],hue=df['color'],palette=['palegreen','violet'])
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(x=df['payment'],hue=df['color'],palette=['palegreen','violet'])
plt.xlabel('payment Mode',fontsize=20,color='red')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(x=df['payment'],hue=df['color'],palette=['green','purple'])
plt.xlabel('payment Mode')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.countplot(x=df['payment'],hue=df['color'],palette=['green','violet'])
plt.xlabel('payment Mode',fontsize=20,color='red')
plt.ylabel('ride counts for taxis',fontsize=20,color='blue')
plt.show()
